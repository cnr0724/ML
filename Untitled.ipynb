# %% [markdown]
# Resume column 데이터 1차 전처리 및 라벨링

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

# %%
data=pd.read_csv(r"C:\Users\Administrator\Desktop\data\data.csv")

# %%
data.head()
# Out:
#    ID Category                                             Resume
# 0   1       HR  b'John H. Smith, P.H.R.\n800-991-5187 | PO Box...
# 1   2       HR  b'Name Surname\nAddress\nMobile No/Email\nPERS...
# 2   3       HR  b'Anthony Brown\nHR Assistant\nAREAS OF EXPERT...
# 3   4       HR  b'www.downloadmela.com\nSatheesh\nEMAIL ID:\nC...
# 4   5       HR  b'HUMAN RESOURCES DIRECTOR\n\xef\x82\xb7Expert...

# %%
applicant=data.iloc[0]
new_data=[]

# %%
for i in range(len(data)):
    if data.iloc[i,2]!="b''":
        new_data.append(data.iloc[i])

# %%
data=pd.DataFrame(new_data)

# %%
import re

# %%
script=applicant[2]
escape_char=re.compile(r'\\x[0123456789abcdref]+')
script=re.sub(escape_char," ", script)

# %%
categories=[]
dic={}
data_length=len(data)

# %%
for i in range(data_length):
    if data.iloc[i,1] not in categories:
        num=len(categories)
        categories.append(data.iloc[i,1])
        dic[data.iloc[i,1]]=num

# %%
print(categories)
print(dic)
# Out:
# ['HR', 'Designing', 'Managment', 'Information Technology', 'Education', 'Advocate', 'Business Development', 'Health & Fitness', 'Agricultural', 'BPO', 'Sales', 'Consultant', 'Digital Media', 'Automobile', 'Food & Beverages', 'Finance', 'Apparel', 'Engineering', 'Accountant', 'Building & Construction', 'Architects', 'Public Relations', 'Banking', 'Arts', 'Aviation']
# {'HR': 0, 'Designing': 1, 'Managment': 2, 'Information Technology': 3, 'Education': 4, 'Advocate': 5, 'Business Development': 6, 'Health & Fitness': 7, 'Agricultural': 8, 'BPO': 9, 'Sales': 10, 'Consultant': 11, 'Digital Media': 12, 'Automobile': 13, 'Food & Beverages': 14, 'Finance': 15, 'Apparel': 16, 'Engineering': 17, 'Accountant': 18, 'Building & Construction': 19, 'Architects': 20, 'Public Relations': 21, 'Banking': 22, 'Arts': 23, 'Aviation': 24}

# %%
label=data['Category']
x=data['Resume']

# %%
x_handled=[]

for i in range(data_length):
    resume=x.iloc[i]
    resume=re.sub(escape_char, '', resume)
    resume=resume.replace('\\n',' ').replace('\n',' ')
    resume=resume[2:]
    x_handled.append(resume)

# %%
df=pd.DataFrame(x_handled)

# %%
df.to_csv(r"C:\Users\Administrator\Desktop\data\df.csv")

# %% [markdown]
# 데이터 2차 전처리

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from tensorflow.keras.preprocessing.text import text_to_word_sequence
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')
regex1=re.compile('^[a-zA-Z]$')
regex2=re.compile('[0-9]+')
stop_words+=[',','(',')','|','$',';','%',':','.',('%c' % 39)]

for i in range(len(x_handled)):
    sentence_token=text_to_word_sequence(x_handled[i])
    result=[]
    for token in sentence_token:
        if token not in stop_words:
            if not regex2.match(token):
                if not regex1.match(token):
                    result.append(token)
    x_handled[i]=' '.join(result)

# %%
df1=pd.DataFrame(x_handled)
df1.to_csv(r"C:\Users\Administrator\Desktop\data\df1.csv")

# %% [markdown]
# Tokenizer 사용.

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(x_handled)
vocab_size=len(tokenizer.word_index)+1

print(vocab_size)
# Out:
# 35341

# %%
resumes_encoded=tokenizer.texts_to_sequences(x_handled)

# %%
p_resumes=pad_sequences(resumes_encoded, maxlen=max([len(resume) for resume in resumes_encoded]), padding='post')

# %%
max([len(resume) for resume in resumes_encoded])
# Out:
# 6530

# %% [markdown]
# label 원핫벡터화

# %%
int_label=[]

# %%
for i in range(len(label)):
    one_hot_vector=[0]*(len(dic))
    index=dic[label.iloc[i]]
    one_hot_vector[index]=1
    int_label.append(one_hot_vector)

# %% [markdown]
# 현재까지 상황 정리

# %%
#x 데이터: p_resumes
#y 데이터: int_label

# %%
dataset=pd.DataFrame(list(zip(p_resumes, int_label)),columns=['x','label'])

# %%
dataset.to_csv(r"C:\Users\Administrator\Desktop\data\p_data.csv")

# %%
#https://wikidocs.net/22933

# %%
tok_dictionary=tokenizer.word_index

print(tok_dictionary)
# Out:
# {'university': 1, 'experience': 2, 'management': 3, 'skills': 4, 'education': 5, 'new': 6, 'project': 7, 'business': 8, 'resume': 9, 'development': 10, 'work': 11, 'design': 12, 'sales': 13, 'school': 14, 'engineering': 15, 'present': 16, 'team': 17, 'research': 18, 'professional': 19, 'com': 20, 'may': 21, 'information': 22, 'training': 23, 'health': 24, 'manager': 25, 'program': 26, 'company': 27, 'college': 28, 'systems': 29, 'system': 30, 'service': 31, 'customer': 32, 'students': 33, 'services': 34, 'computer': 35, 'association': 36, 'science': 37, 'member': 38, 'law': 39, 'position': 40, 'marketing': 41, 'financial': 42, 'use': 43, 'analysis': 44, 'high': 45, 'software': 46, 'projects': 47, 'department': 48, 'career': 49, 'including': 50, 'state': 51, 'activities': 52, 'student': 53, 'time': 54, 'developed': 55, 'job': 56, 'using': 57, 'data': 58, 'office': 59, 'page': 60, 'assistant': 61, 'center': 62, 'knowledge': 63, 'support': 64, 'technical': 65, 'international': 66, 'planning': 67, 'technology': 68, 'national': 69, 'ca': 70, 'communication': 71, 'clients': 72, 'staff': 73, 'client': 74, 'years': 75, 'art': 76, 'co': 77, 'senior': 78, 'conference': 79, 'society': 80, 'year': 81, 'name': 82, 'june': 83, 'annual': 84, 'medical': 85, 'american': 86, 'web': 87, 'committee': 88, 'personal': 89, 'objective': 90, 'process': 91, 'working': 92, 'social': 93, 'email': 94, 'www': 95, 'leadership': 96, 'group': 97, 'managed': 98, 'construction': 99, 'performance': 100, 'product': 101, 'accounting': 102, 'bachelor': 103, 'related': 104, 'list': 105, 'based': 106, 'ability': 107, 'public': 108, 'administration': 109, 'legal': 110, 'one': 111, 'first': 112, 'programs': 113, 'include': 114, 'institute': 115, 'key': 116, 'quality': 117, 'level': 118, 'care': 119, 'well': 120, 'address': 121, 'city': 122, 'designed': 123, 'teaching': 124, 'human': 125, 'york': 126, 'insurance': 127, 'responsible': 128, 'august': 129, 'various': 130, 'community': 131, 'academic': 132, 'organization': 133, 'summer': 134, 'ms': 135, 'board': 136, 'edu': 137, 'sample': 138, 'operations': 139, 'application': 140, 'customers': 141, 'journal': 142, 'general': 143, 'arts': 144, 'strong': 145, 'reports': 146, 'course': 147, 'issues': 148, 'april': 149, 'special': 150, 'gpa': 151, 'media': 152, 'provided': 153, 'assisted': 154, 'excellent': 155, 'microsoft': 156, 'created': 157, 'phone': 158, 'responsibilities': 159, 'part': 160, 'director': 161, 'major': 162, 'review': 163, 'within': 164, 'needs': 165, 'summary': 166, 'provide': 167, 'ny': 168, 'references': 169, 'english': 170, 'worked': 171, 'writing': 172, 'finance': 173, 'used': 174, 'environment': 175, 'date': 176, 'current': 177, 'relevant': 178, 'september': 179, 'requirements': 180, 'market': 181, 'graduate': 182, 'engineer': 183, 'products': 184, 'qualifications': 185, 'procedures': 186, 'accounts': 187, 'florida': 188, 'applications': 189, 'corporate': 190, 'employment': 191, 'degree': 192, 'employees': 193, 'study': 194, 'resources': 195, 'bank': 196, 'award': 197, 'mechanical': 198, 'street': 199, 'site': 200, 'fall': 201, 'best': 202, 'safety': 203, 'two': 204, 'spring': 205, 'control': 206, 'history': 207, 'building': 208, 'inc': 209, 'january': 210, 'march': 211, 'developing': 212, 'field': 213, 'also': 214, 'excel': 215, 'july': 216, 'good': 217, 'st': 218, 'hr': 219, 'implemented': 220, 'make': 221, 'available': 222, 'maintained': 223, 'materials': 224, 'employee': 225, 'relations': 226, 'online': 227, 'lead': 228, 'equipment': 229, 'ensure': 230, 'dr': 231, 'develop': 232, 'managing': 233, 'pa': 234, 'october': 235, 'languages': 236, 'paper': 237, 'programming': 238, 'dental': 239, 'create': 240, 'studies': 241, 'presented': 242, 'north': 243, 'implementation': 244, 'intern': 245, 'prepared': 246, 'president': 247, 'word': 248, 'database': 249, 'cost': 250, 'solutions': 251, 'december': 252, 'advanced': 253, 'honors': 254, 'meeting': 255, 'learning': 256, 'volunteer': 257, 'providing': 258,  ...

# %%
new_dictionary={}

regex3=re.compile('^[a-z][a-z][a-z]$',re.I)
regex4=re.compile('^[a-z][a-z]$', re.I)
for key in tok_dictionary:
    add1=True
    if regex1.match(key) or regex2.match(key) or regex3.match(key) or regex4.match(key):
        add1=False
        
    if add1==True:
        new_dictionary[key]=len(new_dictionary.keys())

# %%
print(len(new_dictionary.keys()), len(tok_dictionary.keys()))
# Out:
# 32768 35340

# %%
frequency_dictionary={}
for key in new_dictionary:
    frequency_dictionary[key]=0

    for i in range(len(x_handled)):
        re1=[]
        if key in x_handled[i].split():
            re1=re.findall('\\b'+key+'\\b',x_handled[i],flags=re.IGNORECASE)
        frequency_dictionary[key]+=len(re1)+1

# %%
frequency_dictionary
# Out:
# {'university': 4472,
#  'experience': 4297,
#  'management': 4239,
#  'skills': 3980,
#  'education': 3572,
#  'project': 3384,
#  'business': 3306,
#  'resume': 3198,
#  'development': 3092,
#  'work': 3040,
#  'design': 2992,
#  'sales': 2945,
#  'school': 2924,
#  'engineering': 2791,
#  'present': 2747,
#  'team': 2676,
#  'research': 2652,
#  'professional': 2633,
#  'information': 2440,
#  'training': 2356,
#  'health': 2324,
#  'manager': 2312,
#  'program': 2303,
#  'company': 2309,
#  'college': 2266,
#  'systems': 2249,
#  'system': 2252,
#  'service': 2208,
#  'customer': 2194,
#  'students': 2194,
#  'services': 2178,
#  'computer': 2175,
#  'association': 2129,
#  'science': 2125,
#  'member': 2118,
#  'position': 2092,
#  'marketing': 2090,
#  'financial': 2072,
#  'analysis': 2044,
#  'high': 2040,
#  'software': 2040,
#  'projects': 2037,
#  'department': 2012,
#  'career': 2008,
#  'including': 2003,
#  'state': 1991,
#  'activities': 1980,
#  'student': 1979,
#  'time': 1976,
#  'developed': 1969,
#  'using': 1956,
#  'data': 1953,
#  'office': 1950,
#  'page': 1931,
#  'assistant': 1922,
#  'center': 1906,
#  'knowledge': 1888,
#  'support': 1886,
#  'technical': 1881,
#  'international': 1876,
#  'planning': 1882,
#  'technology': 1849,
#  'national': 1841,
#  'communication': 1808,
#  'clients': 1812,
#  'staff': 1796,
#  'client': 1797,
#  'years': 1790,
#  'senior': 1757,
#  'conference': 1757,
#  'society': 1746,
#  'year': 1739,
#  'name': 1731,
#  'june': 1730,
#  'annual': 1725,
#  'medical': 1720,
#  'american': 1718,
#  'committee': 1711,
#  'personal': 1705,
#  'objective': 1704,
#  'process': 1695,
#  'working': 1690,
#  'social': 1690,
#  'email': 1694,
#  'leadership': 1683,
#  'group': 1682,
#  'managed': 1678,
#  'construction': 1676,
#  'performance': 1665,
#  'product': 1657,
#  'accounting': 1656,
#  'bachelor': 1654,
#  'related': 1651,
#  'list': 1650,
#  'based': 1648,
#  'ability': 1647,
#  'public': 1647,
#  'administration': 1646,
#  'legal': 1642,
#  'first': 1634,
#  'programs': 1626,
#  'include': 1621,
#  'institute': 1621,
#  'quality': 1619,
#  'level': 1617,
#  'care': 1613,
#  'well': 1610,
#  'address': 1599,
#  'city': 1598,
#  'designed': 1595,
#  'teaching': 1596,
#  'human': 1590,
#  'york': 1590,
#  'insurance': 1589,
#  'responsible': 1588,
#  'august': 1582,
#  'various': 1581,
#  'community': 1580,
#  'academic': 1573,
#  'organization': 1575,
#  'summer': 1565,
#  'board': 1551,
#  'sample': 1550,
#  'operations': 1545,
#  'application': 1540,
#  'customers': 1542,
#  'journal': 1538,
#  'general': 1536,
#  'arts': 1536,
#  'strong': 1533,
#  'reports': 1532,
#  'course': 1532,
#  'issues': 1524,
#  'april': 1524,
#  'special': 1526,
#  'media': 1521,
#  'provided': 1516,
#  'assisted': 1515,
#  'excellent': 1514,
#  'microsoft': 1516,
#  'created': 1512,
#  'phone': 1510,
#  'responsibilities': 1506,
#  'part': 1504,
#  'director': 1506,
#  'major': 1497,
#  'review': 1495,
#  'within': 1493,
#  'needs': 1494,
#  'summary': 1487,
#  'provide': 1486,
#  'references': 1483,
#  'english': 1481,
#  'worked': 1478,
#  'writing': 1475,
#  'finance': 1475,
#  'used': 1471,
#  'environment': 1469,
#  'date': 1469,
#  'current': 1468,
#  'relevant': 1467,
#  'september': 1467,
#  'requirements': 1465,
#  'market': 1465,
#  'graduate': 1465,
#  'engineer': 1465,
#  'products': 1465,
#  'qualifications': 1463,
#  'procedures': 1462,
#  'accounts': 1464,
#  'florida': 1461,
#  'applications': 1457,
#  'corporate': 1454,
#  'employment': 1453,
#  'degree': 1453,
#  'employees': 1454,
#  'study': 1450,
#  'resources': 1443,
#  'bank': 1448,
#  'award': 1442,
#  'mechanical': 1440,
#  'street': 1440,
#  'site': 1436,
#  'fall': 1433,
#  'best': 1436,
#  'safety': 1431,
#  'spring': 1428,
#  'control': 1427,
#  'history': 1427,
#  'building': 1426,
#  'january': 1424,
#  'march': 1423,
#  'developing': 1420,
#  'field': 1420,
#  'also': 1419,
#  'excel': 1420,
#  'july': 1417,
#  'good': 1414,
#  'implemented': 1409,
#  'make': 1409,
#  'available': 1405,
#  'maintained': 1403,
#  'materials': 1402,
#  'employee': 1401,
#  'relations': 1400,
#  'online': 1400,
#  'lead': 1395,
#  'equipment': 1394,
#  'ensure': 1391,
#  'develop': 1387,
#  'managing': 1387,
#  'october': 1384,
#  'languages': 1384,
#  'paper': 1384,
#  'programming': 1384,
#  'dental': 1382,
#  'create': 1379,
#  'studies': 1378,
#  'presented': 1378,
#  'north': 1377,
#  'implementation': 1374,
#  'intern': 1374,
#  'prepared': 1373,
#  'president': 1373,
#  'word': 1371,
#  'database': 1368,
#  'cost': 1367,
#  'solutions': 1367,
#  'december': 1366,
#  'advanced': 1367,
#  'honors': 1365,
#  'meeting': 1363,
#  'learning': 1362,
#  'volunteer': 1362,
#  'providing': 1361,
#  'letter': 1361,
#  'practice': 1361,
#  'presentation': 1359,
#  'production': 1359,
#  'sports': 1359,
#  'cover': 1357,
#  'help': 1357,
#  'curriculum': 1356,
#  'effective': 1357,
#  'order': 1355,
#  'conducted': 1355,
#  'plans': 1354,
#  'hospital': 1356,
#  'plan': 1351,
#  'areas': 1351,
#  'executive': 1349,
#  'testing': 1349,
#  'account': 1348,
#  'performed': 1348,
#  'clinical': 1348,
#  'industry': 1343,
#  'windows': 1343,
#  'million': 1341,
#  'title': 1342,
#  'faculty': 1341,
#  'educational': 1340,
#  'strategies': 1338,
#  'language': 1338,
#  'organized': 1335,
#  'nutrition': 1336,
#  'reporting': 1334,
#  'class': 1334,
#  'included': 1334,
#  'strategic': 1333,
#  'processes': 1332,
#  'engineers': 1332,
#  'risk': 1331,
#  'role': 1329,
#  'specific': 1329,
#  'professor': 1328,
#  'civil': 1327,
#  'smith': 1325,
#  'tools': 1324,
#  'test': 1324,
#  'example': 1322,
#  'washington': 1319,
#  'budget': 1318,
#  'november': 1318,
#  'results': 1317,
#  'daily': 1316,
#  'selected': 1315,
#  'content': 1314,
#  'dentistry': 1315,
#  'additional': 1311,
#  'communications': 1309,
#  'analyst': 1311,
#  'associate': 1309,
#  'meetings': 1308,
#  'preparation': 1308,
#  'events': 1307,
#  'duties': 1306,
#  'three': 1307,
#  'february': 1306,
#  'consulting': 1304,
#  'mail': 1303,
#  'action': 1301,
#  'basic': 1303,
#  'india': 1301,
#  'digital': 1299,
#  'economics': 1299,
#  'food': 1299,
#  'teams': 1298,
#  'consultant': 1297,
#  'manage': 1295,
#  'making': 1296,
#  'growth': 1295,
#  'teacher': 1297,
#  'members': 1294,
#  'presentations': 1294,
#  'appropriate': 1293,
#  'completed': 1292,
#  'internal': 1290,
#  'resumes': 1292,
#  'full': 1291,
#  'monthly': 1288,
#  'java': 1289,
#  'coordinated': 1288,
#  'problem': 1287,
#  'network': 1287,
#  'master': 1288,
#  'burke': 1287,
#  'managers': 1286,
#  'line': 1286,
#  'written': 1285,
#  'number': 1285,
#  'section': 1285,
#  'user': 1285,
#  'experiences': 1284,
#  'operating': 1283,
#  'certificate': 1282,
#  'mississippi': 1286,
#  'council': 1281,
#  'policy': 1282,
#  'chicago': 1279,
#  'contact': 1275,
#  'month': 1275,
#  'california': 1276,
#  'expertise': 1274,
#  'children': 1276,
#  'maintenance': 1274,
#  'area': 1273,
#  'home': 1273,
#  'case': 1272,
#  'achievements': 1272,
#  'courses': 1272,
#  'dawson': 1272,
#  'policies': 1271,
#  'real': 1271,
#  'model': 1271,
#  'patients': 1272,
#  'xxxx': 1270,
#  'request': 1276,
#  'creative': 1269,
#  'electrical': 1268,
#  'division': 1268,
#  'chair': 1267,
#  'treatment': 1268,
#  'able': 1266,
#  'world': 1267,
#  'internship': 1266,
#  'goals': 1265,
#  'certified': 1265,
#  'functional': 1264,
#  'website': 1266,
#  'administrative': 1263,
#  'local': 1263,
#  'like': 1262,
#  'life': 1261,
#  'awards': 1261,
#  'accomplishments': 1262,
#  'creating': 1261,
#  'dates': 1261,
#  'club': 1261,
#  'meet': 1260,
#  'supervised': 1259,
#  'people': 1259,
#  'technologies': 1260,
#  'problems': 1256,
#  'different': 1255,
#  'developer': 1255,
#  'campus': 1255,
#  'gallery': 1255,
#  'global': 1254,
#  'details': 1253,
#  'tasks': 1252,
#  'visual': 1252,
#  'implant': 1252,
#  'strategy': 1250,
#  'multiple': 1249,
#  'report': 1249,
#  'power': 1249,
#  'county': 1248,
#  'resource': 1245,
#  'template': 1244,
#  'cell': 1244,
#  'revenue': 1243,
#  'html': 1243,
#  'upon': 1243,
#  'leader': 1241,
#  'organizational': 1241,
#  'contract': 1241,
#  'companies': 1240,
#  'analyzed': 1240,
#  'commercial': 1240,
#  'employer': 1243,
#  'cash': 1239,
#  'manufacturing': 1238,
#  'techniques': 1238,
#  'access': 1237,
#  'proficient': 1237,
#  'mobile': 1235,
#  'government': 1235,
#  'personnel': 1232,
#  'record': 1232,
#  'interests': 1232,
#  'dayjob': 1232,
#  'representative': 1232,
#  'foundation': 1231,
#  'standards': 1230,
#  'required': 1230,
#  'pittsburgh': 1231,
#  'grant': 1227,
#  'built': 1226,
#  'scholarship': 1226,
#  'handling': 1226,
#  'recruitment': 1225,
#  'spanish': 1225,
#  'house': 1224,
#  'status': 1224,
#  'highly': 1223,
#  'successfully': 1222,
#  'experienced': 1222,
#  'large': 1221,
#  'assist': 1221,
#  'interview': 1221,
#  'entry': 1221,
#  'involved': 1220,
#  'stanford': 1220,
#  'water': 1219,
#  'designer': 1219,
#  'relationship': 1218,
#  'compliance': 1218,
#  'format': 1218,
#  'capital': 1218,
#  'positions': 1218,
#  'multi': 1220,
#  'supervisor': 1217,
#  'drive': 1216,
#  'understanding': 1215,
#  'records': 1215,
#  'place': 1215,
#  'following': 1215,
#  'complex': 1214,
#  'description': 1214,
#  'extensive': 1213,
#  'increased': 1213,
#  'document': 1213,
#  'banking': 1213,
#  'press': 1212,
#  'change': 1212,
#  'firm': 1211,
#  'powerpoint': 1211,
#  'read': 1210,
#  'directed': 1210,
#  'interest': 1210,
#  'space': 1211,
#  'http': 1210,
#  'processing': 1209,
#  'long': 1209,
#  'vice': 1208,
#  'retail': 1208,
#  'maintaining': 1207,
#  'internet': 1207,
#  'deans': 1207,
#  'delivery': 1206,
#  'flight': 1207,
#  'illinois': 1206,
#  'individual': 1206,
#  'relationships': 1205,
#  'would': 1206,
#  'reference': 1204,
#  'maintain': 1204,
#  'post': 1204,
#  'self': 1203,
#  'server': 1203,
#  'search': 1203,
#  'simmons': 1203,
#  'united': 1202,
#  "'s": 989,
#  'museum': 1202,
#  'point': 1203,
#  'made': 1201,
#  'weekly': 1201,
#  'certification': 1200,
#  'solving': 1200,
#  'unit': 1200,
#  'canada': 1200,
#  'decision': 1199,
#  'please': 1199,
#  'wrote': 1199,
#  'expected': 1199,
#  'john': 1201,
#  'implementing': 1199,
#  'trained': 1198,
#  'jacksonville': 1198,
#  'profile': 1197,
#  'opportunities': 1197,
#  'documents': 1197,
#  'head': 1197,
#  'coordinator': 1197,
#  'successful': 1197,
#  'participated': 1197,
#  'track': 1196,
#  'seeking': 1196,
#  'opportunity': 1196,
#  'district': 1196,
#  'travel': 1195,
#  'oral': 1195,
#  'direct': 1195,
#  'patient': 1195,
#  'coursework': 1195,
#  'magazine': 1195,
#  'several': 1194,
#  'diploma': 1194,
#  'analytical': 1193,
#  'grade': 1193,
#  'healthcare': 1192,
#  'schools': 1192,
#  'medicine': 1193,
#  'integrated': 1192,
#  'leading': 1191,
#  'background': 1190,
#  'evaluation': 1190,
#  'road': 1190,
#  'linux': 1189,
#  'economic': 1188,
#  'employers': 1187,
#  'improve': 1187,
#  'build': 1187,
#  'practices': 1186,
#  'chronological': 1186,
#  'improved': 1185,
#  'gmail': 1185,
#  'private': 1185,
#  'established': 1185,
#  'future': 1186,
#  'statements': 1186,
#  'increase': 1183,
#  'levels': 1183,
#  'documentation': 1183,
#  'junior': 1183,
#  'french': 1184,
#  'core': 1181,
#  'south': 1181,
#  'competition': 1181,
#  'supervision': 1181,
#  'publications': 1181,
#  'functions': 1180,
#  'cross': 1180,
#  'regional': 1180,
#  'impact': 1180,
#  'academy': 1180,
#  'security': 1179,
#  'person': 1179,
#  'potential': 1179,
#  'obtain': 1179,
#  'court': 1179,
#  'organizations': 1178,
#  'across': 1178,
#  'letters': 1177,
#  'store': 1179,
#  'demonstrated': 1177,
#  'undergraduate': 1177,
#  'received': 1176,
#  'months': 1176,
#  'adobe': 1176,
#  'small': 1175,
#  'served': 1175,
#  'schedule': 1175,
#  'hours': 1175,
#  'accountant': 1175,
#  'oracle': 1174,
#  'honor': 1174,
#  'info': 1173,
#  'prepare': 1173,
#  'higher': 1173,
#  'identify': 1173,
#  'benefits': 1172,
#  'brand': 1173,
#  'carolina': 1172,
#  'interpersonal': 1171,
#  'questions': 1171,
#  'oriented': 1171,
#  'texas': 1171,
#  'existing': 1169,
#  'expert': 1170,
#  'groups': 1169,
#  'assessment': 1169,
#  'industrial': 1169,
#  'inventory': 1169,
#  'minor': 1169,
#  'migration': 1169,
#  'tufts': 1169,
#  'detail': 1168,
#  'effectively': 1168,
#  'workshop': 1169,
#  'methods': 1168,
#  'advertising': 1168,
#  'thesis': 1168,
#  'ensuring': 1167,
#  'attended': 1167,
#  'main': 1167,
#  'taught': 1167,
#  'many': 1166,
#  'states': 1166,
#  'helped': 1166,
#  'principal': 1165,
#  'associates': 1165,
#  'london': 1165,
#  'show': 1165,
#  'seminar': 1165,
#  'specialist': 1164,
#  'code': 1164,
#  'applied': 1164,
#  'responsibility': 1163,
#  'payroll': 1162,
#  'researched': 1162,
#  'models': 1162,
#  'property': 1162,
#  'artist': 1162,
#  'complete': 1161,
#  'cases': 1161,
#  'outstanding': 1161,
#  'material': 1160,
#  'boston': 1160,
#  'nursing': 1160,
#  'corporation': 1159,
#  'looking': 1159,
#  'improvement': 1159,
#  'flow': 1160,
#  'chemical': 1159,
#  'satisfaction': 1158,
#  'contracts': 1158,
#  'handled': 1158,
#  'graduation': 1158,
#  'chapter': 1158,
#  'planned': 1158,
#  'chinese': 1158,
#  'indiana': 1157,
#  'collaborated': 1156,
#  'overall': 1156,
#  'physical': 1156,
#  'week': 1156,
#  'implement': 1155,
#  'location': 1155,
#  'book': 1155,
#  'therapy': 1155,
#  'identified': 1154,
#  'costs': 1154,
#  'architecture': 1154,
#  'enterprise': 1153,
#  'achieved': 1153,
#  'culture': 1153,
#  'resulting': 1153,
#  'look': 1153,
#  'carnegie': 1153,
#  'awarded': 1152,
#  'integration': 1152,
#  'since': 1152,
#  'fashion': 1152,
#  'teachers': 1152,
#  'laboratory': 1151,
#  'value': 1150,
#  'advisory': 1150,
#  'west': 1150,
#  'central': 1150,
#  'preparing': 1152,
#  'standard': 1150,
#  'fluent': 1152,
#  'music': 1150,
#  'want': 1150,
#  'works': 1150,
#  'type': 1149,
#  'china': 1149,
#  'advisor': 1149,
#  'important': 1148,
#  'evaluated': 1148,
#  'force': 1148,
#  'graphic': 1148,
#  'reviewed': 1148,
#  'sure': 1148,
#  'white': 1148,
#  'verbs': 1148,
#  'estate': 1149,
#  'departments': 1147,
#  'portfolio': 1148,
#  'monitoring': 1145,
#  'vitae': 1145,
#  'modeling': 1145,
#  'reading': 1145,
#  'setting': 1144,
#  'plant': 1144,
#  'concepts': 1144,
#  'perform': 1143,
#  'environmental': 1143,
#  'call': 1143,
#  'throughout': 1143,
#  'ideas': 1143,
#  'great': 1143,
#  'restorative': 1144,
#  'applying': 1142,
#  'mellon': 1142,
#  'homoeopathic': 1142,
#  'statement': 1141,
#  'promoted': 1141,
#  'federal': 1141,
#  'examples': 1143,
#  'variety': 1141,
#  'energy': 1140,
#  'five': 1140,
#  'transactions': 1140,
#  'objectives': 1140,
#  'open': 1139,
#  'write': 1139,
#  'ensured': 1139,
#  'counseling': 1139,
#  'alumni': 1139,
#  'monash': 1139,
#  'possible': 1138,
#  'external': 1138,
#  'guide': 1138,
#  'exceptional': 1138,
#  'sciences': 1139,
#  'infrastructure': 1137,
#  'proven': 1137,
#  'women': 1138,
#  'kovner': 1137,
#  'brown': 1136,
#  'progress': 1136,
#  'take': 1138,
#  'four': 1136,
#  'youth': 1136,
#  'studio': 1137,
#  'wide': 1135,
#  'officer': 1135,
#  'suite': 1135,
#  'consumer': 1135,
#  'currently': 1137,
#  'america': 1135,
#  'chemistry': 1135,
#  'focus': 1134,
#  'skilled': 1134,
#  'efficiency': 1135,
#  'elementary': 1134,
#  'autocad': 1134,
#  'homoeopathy': 1134,
#  'chawla': 1134,
#  'follow': 1133,
#  'prior': 1133,
#  'middle': 1133,
#  'designing': 1133,
#  'credit': 1133,
#  'orders': 1133,
#  'trends': 1132,
#  'park': 1132,
#  'range': 1132,
#  'facilitated': 1132,
#  'aspects': 1132,
#  'family': 1132,
#  'regarding': 1131,
#  'held': 1131,
#  'focused': 1131,
#  'users': 1131,
#  'highlights': 1131,
#  'electronic': 1130,
#  'event': 1130,
#  'distribution': 1130,
#  'photoshop': 1130,
#  'custom': 1130,
#  'changes': 1129,
#  'structure': 1129,
#  'active': 1129,
#  'francisco': 1129,
#  'east': 1129,
#  'artwork': 1129,
#  'exhibition': 1129,
#  'without': 1128,
#  'final': 1128,
#  'success': 1128,
#  'scheduling': 1128,
#  'hands': 1128,
#  'markets': 1128,
#  'angeles': 1128,
#  'recent': 1128,
#  'baltimore': 1128,
#  'base': 1127,
#  'initiatives': 1127,
#  'critical': 1127,
#  'instructor': 1127,
#  'careers': 1127,
#  'investment': 1127,
#  'utilizing': 1127,
#  'editor': 1127,
#  'dean': 1131,
#  'qualification': 1126,
#  'must': 1127,
#  'jobs': 1126,
#  'term': 1126,
#  'classroom': 1126,
#  'unix': 1126,
#  'delivered': 1125,
#  'limited': 1125,
#  'second': 1125,
#  'avenue': 1125,
#  'effects': 1125,
#  'excellence': 1124,
#  'positive': 1124,
#  'keep': 1124,
#  'awareness': 1124,
#  'secondary': 1124,
#  'telephone': 1124,
#  'task': 1124,
#  'pediatric': 1124,
#  'motivated': 1123,
#  'principles': 1124,
#  'times': 1123,
#  'compensation': 1122,
#  'abilities': 1122,
#  'tracking': 1122,
#  'feedback': 1122,
#  'delhi': 1122,
#  'javascript': 1122,
#  'professionals': 1122,
#  'skill': 1121,
#  'basis': 1121,
#  'oversaw': 1121,
#  'achievement': 1121,
#  'selection': 1121,
#  'assigned': 1121,
#  'gained': 1121,
#  'minnesota': 1121,
#  'dynamic': 1120,
#  'innovative': 1120,
#  'need': 1120,
#  'australia': 1120,
#  'start': 1120,
#  'pressure': 1120,
#  'produced': 1119,
#  'diverse': 1119,
#  'copy': 1119,
#  'minneapolis': 1119,
#  'style': 1119,
#  'jackson': 1119,
#  'virginia': 1120,
#  'significant': 1118,
#  'others': 1118,
#  'salary': 1118,
#  'assisting': 1118,
#  'nebraska': 1118,
#  'matlab': 1118,
#  'websites': 1117,
#  'check': 1117,
#  'hardware': 1117,
#  'calls': 1116,
#  'video': 1116,
#  'source': 1116,
#  'hiring': 1115,
#  'update': 1116,
#  'installation': 1115,
#  'biomedical': 1115,
#  'communicate': 1114,
#  'conduct': 1114,
#  'candidates': 1114,
#  'assistance': 1114,
#  'branch': 1114,
#  'includes': 1114,
#  'last': 1114,
#  'occupational': 1114,
#  'agency': 1115,
#  'edition': 1114,
#  'independent': 1114,
#  'fixed': 1114,
#  'approach': 1113,
#  'efforts': 1113,
#  'mysql': 1113,
#  'green': 1113,
#  'execution': 1112,
#  'supply': 1112,
#  'introduction': 1112,
#  'sport': 1112,
#  'classes': 1112,
#  'size': 1112,
#  'analyze': 1111,
#  'candidate': 1112,
#  'child': 1111,
#  'negotiated': 1111,
#  'contributed': 1111,
#  'supported': 1111,
#  'lines': 1112,
#  'past': 1111,
#  'emergency': 1111,
#  'copyright': 1110,
#  'sessions': 1110,
#  'recommendations': 1110,
#  'sept': 1110,
#  'interface': 1110,
#  'font': 1110,
#  'profit': 1110,
#  'restaurant': 1111,
#  'generation': 1109,
#  'short': 1109,
#  'operational': 1109,
#  'tool': 1109,
#  'necessary': 1109,
#  'birth': 1109,
#  'firms': 1110,
#  'performing': 1109,
#  'proficiency': 1109,
#  'residential': 1109,
#  'graphics': 1109,
#  'google': 1109,
#  'photography': 1109,
#  'published': 1109,
#  'achieve': 1108,
#  'creation': 1108,
#  'interviews': 1108,
#  'embedded': 1108,
#  'reviews': 1108,
#  'know': 1108,
#  'body': 1108,
#  'sponsor': 1108,
#  'companys': 1107,
#  'collection': 1107,
#  'seminars': 1107,
#  'platform': 1107,
#  'needed': 1107,
#  'analyzing': 1106,
#  'conducting': 1106,
#  'regular': 1106,
#  'free': 1106,
#  'centre': 1106,
#  'budgets': 1106,
#  'technician': 1106,
#  'schedules': 1106,
#  'completion': 1106,
#  'disabilities': 1107,
#  'apply': 1105,
#  'single': 1105,
#  'coordinating': 1105,
#  'monitor': 1105,
#  'attendance': 1105,
#  'articles': 1105,
#  'assembly': 1105,
#  'properties': 1105,
#  'maryland': 1105,
#  'david': 1105,
#  'guidelines': 1105,
#  'coordinate': 1104,
#  'learn': 1105,
#  'every': 1104,
#  'utilized': 1104,
#  'certifications': 1104,
#  'conferences': 1104,
#  'pages': 1104,
#  'news': 1104,
#  'juried': 1104,
#  'denver': 1104,
#  'houston': 1104,
#  'files': 1103,
#  'competitive': 1103,
#  'player': 1103,
#  'sites': 1103,
#  'specifications': 1103,
#  'mass': 1103,
#  'known': 1103,
#  'solution': 1103,
#  'describe': 1103,
#  'library': 1103,
#  'fund': 1103,
#  'scholar': 1103,
#  'mathematics': 1103,
#  'deadlines': 1102,
#  'front': 1102,
#  'organizing': 1102,
#  'affairs': 1102,
#  'print': 1102,
#  'facility': 1102,
#  'session': 1102,
#  'campaigns': 1102,
#  'claims': 1101,
#  'early': 1101,
#  'controls': 1101,
#  'resolution': 1101,
#  'placement': 1101,
#  'campaign': 1101,
#  ...}

# %%
frequency_list=sorted(frequency_dictionary.items(), key=(lambda x:x[1]), reverse=True)

# %%
frequency_list
# Out:
# [('university', 4472),
#  ('experience', 4297),
#  ('management', 4239),
#  ('skills', 3980),
#  ('education', 3572),
#  ('project', 3384),
#  ('business', 3306),
#  ('resume', 3198),
#  ('development', 3092),
#  ('work', 3040),
#  ('design', 2992),
#  ('sales', 2945),
#  ('school', 2924),
#  ('engineering', 2791),
#  ('present', 2747),
#  ('team', 2676),
#  ('research', 2652),
#  ('professional', 2633),
#  ('information', 2440),
#  ('training', 2356),
#  ('health', 2324),
#  ('manager', 2312),
#  ('company', 2309),
#  ('program', 2303),
#  ('college', 2266),
#  ('system', 2252),
#  ('systems', 2249),
#  ('service', 2208),
#  ('customer', 2194),
#  ('students', 2194),
#  ('services', 2178),
#  ('computer', 2175),
#  ('association', 2129),
#  ('science', 2125),
#  ('member', 2118),
#  ('position', 2092),
#  ('marketing', 2090),
#  ('financial', 2072),
#  ('analysis', 2044),
#  ('high', 2040),
#  ('software', 2040),
#  ('projects', 2037),
#  ('department', 2012),
#  ('career', 2008),
#  ('including', 2003),
#  ('state', 1991),
#  ('activities', 1980),
#  ('student', 1979),
#  ('time', 1976),
#  ('developed', 1969),
#  ('using', 1956),
#  ('data', 1953),
#  ('office', 1950),
#  ('page', 1931),
#  ('assistant', 1922),
#  ('center', 1906),
#  ('knowledge', 1888),
#  ('support', 1886),
#  ('planning', 1882),
#  ('technical', 1881),
#  ('international', 1876),
#  ('technology', 1849),
#  ('national', 1841),
#  ('clients', 1812),
#  ('communication', 1808),
#  ('client', 1797),
#  ('staff', 1796),
#  ('years', 1790),
#  ('senior', 1757),
#  ('conference', 1757),
#  ('society', 1746),
#  ('year', 1739),
#  ('name', 1731),
#  ('june', 1730),
#  ('annual', 1725),
#  ('medical', 1720),
#  ('american', 1718),
#  ('committee', 1711),
#  ('personal', 1705),
#  ('objective', 1704),
#  ('process', 1695),
#  ('email', 1694),
#  ('working', 1690),
#  ('social', 1690),
#  ('leadership', 1683),
#  ('group', 1682),
#  ('managed', 1678),
#  ('construction', 1676),
#  ('performance', 1665),
#  ('product', 1657),
#  ('accounting', 1656),
#  ('bachelor', 1654),
#  ('related', 1651),
#  ('list', 1650),
#  ('based', 1648),
#  ('ability', 1647),
#  ('public', 1647),
#  ('administration', 1646),
#  ('legal', 1642),
#  ('first', 1634),
#  ('programs', 1626),
#  ('include', 1621),
#  ('institute', 1621),
#  ('quality', 1619),
#  ('level', 1617),
#  ('care', 1613),
#  ('well', 1610),
#  ('address', 1599),
#  ('city', 1598),
#  ('teaching', 1596),
#  ('designed', 1595),
#  ('human', 1590),
#  ('york', 1590),
#  ('insurance', 1589),
#  ('responsible', 1588),
#  ('august', 1582),
#  ('various', 1581),
#  ('community', 1580),
#  ('organization', 1575),
#  ('academic', 1573),
#  ('summer', 1565),
#  ('board', 1551),
#  ('sample', 1550),
#  ('operations', 1545),
#  ('customers', 1542),
#  ('application', 1540),
#  ('journal', 1538),
#  ('general', 1536),
#  ('arts', 1536),
#  ('strong', 1533),
#  ('reports', 1532),
#  ('course', 1532),
#  ('special', 1526),
#  ('issues', 1524),
#  ('april', 1524),
#  ('media', 1521),
#  ('provided', 1516),
#  ('microsoft', 1516),
#  ('assisted', 1515),
#  ('excellent', 1514),
#  ('created', 1512),
#  ('phone', 1510),
#  ('responsibilities', 1506),
#  ('director', 1506),
#  ('part', 1504),
#  ('major', 1497),
#  ('review', 1495),
#  ('needs', 1494),
#  ('within', 1493),
#  ('summary', 1487),
#  ('provide', 1486),
#  ('references', 1483),
#  ('english', 1481),
#  ('worked', 1478),
#  ('writing', 1475),
#  ('finance', 1475),
#  ('used', 1471),
#  ('environment', 1469),
#  ('date', 1469),
#  ('current', 1468),
#  ('relevant', 1467),
#  ('september', 1467),
#  ('requirements', 1465),
#  ('market', 1465),
#  ('graduate', 1465),
#  ('engineer', 1465),
#  ('products', 1465),
#  ('accounts', 1464),
#  ('qualifications', 1463),
#  ('procedures', 1462),
#  ('florida', 1461),
#  ('applications', 1457),
#  ('corporate', 1454),
#  ('employees', 1454),
#  ('employment', 1453),
#  ('degree', 1453),
#  ('study', 1450),
#  ('bank', 1448),
#  ('resources', 1443),
#  ('award', 1442),
#  ('mechanical', 1440),
#  ('street', 1440),
#  ('site', 1436),
#  ('best', 1436),
#  ('fall', 1433),
#  ('safety', 1431),
#  ('spring', 1428),
#  ('control', 1427),
#  ('history', 1427),
#  ('building', 1426),
#  ('january', 1424),
#  ('march', 1423),
#  ('developing', 1420),
#  ('field', 1420),
#  ('excel', 1420),
#  ('also', 1419),
#  ('july', 1417),
#  ('good', 1414),
#  ('implemented', 1409),
#  ('make', 1409),
#  ('available', 1405),
#  ('maintained', 1403),
#  ('materials', 1402),
#  ('employee', 1401),
#  ('relations', 1400),
#  ('online', 1400),
#  ('lead', 1395),
#  ('equipment', 1394),
#  ('ensure', 1391),
#  ('develop', 1387),
#  ('managing', 1387),
#  ('october', 1384),
#  ('languages', 1384),
#  ('paper', 1384),
#  ('programming', 1384),
#  ('dental', 1382),
#  ('create', 1379),
#  ('studies', 1378),
#  ('presented', 1378),
#  ('north', 1377),
#  ('implementation', 1374),
#  ('intern', 1374),
#  ('prepared', 1373),
#  ('president', 1373),
#  ('word', 1371),
#  ('database', 1368),
#  ('cost', 1367),
#  ('solutions', 1367),
#  ('advanced', 1367),
#  ('december', 1366),
#  ('honors', 1365),
#  ('meeting', 1363),
#  ('learning', 1362),
#  ('volunteer', 1362),
#  ('providing', 1361),
#  ('letter', 1361),
#  ('practice', 1361),
#  ('presentation', 1359),
#  ('production', 1359),
#  ('sports', 1359),
#  ('cover', 1357),
#  ('help', 1357),
#  ('effective', 1357),
#  ('curriculum', 1356),
#  ('hospital', 1356),
#  ('order', 1355),
#  ('conducted', 1355),
#  ('plans', 1354),
#  ('plan', 1351),
#  ('areas', 1351),
#  ('executive', 1349),
#  ('testing', 1349),
#  ('account', 1348),
#  ('performed', 1348),
#  ('clinical', 1348),
#  ('industry', 1343),
#  ('windows', 1343),
#  ('title', 1342),
#  ('million', 1341),
#  ('faculty', 1341),
#  ('educational', 1340),
#  ('strategies', 1338),
#  ('language', 1338),
#  ('nutrition', 1336),
#  ('organized', 1335),
#  ('reporting', 1334),
#  ('class', 1334),
#  ('included', 1334),
#  ('strategic', 1333),
#  ('processes', 1332),
#  ('engineers', 1332),
#  ('risk', 1331),
#  ('role', 1329),
#  ('specific', 1329),
#  ('professor', 1328),
#  ('civil', 1327),
#  ('smith', 1325),
#  ('tools', 1324),
#  ('test', 1324),
#  ('example', 1322),
#  ('washington', 1319),
#  ('budget', 1318),
#  ('november', 1318),
#  ('results', 1317),
#  ('daily', 1316),
#  ('selected', 1315),
#  ('dentistry', 1315),
#  ('content', 1314),
#  ('additional', 1311),
#  ('analyst', 1311),
#  ('communications', 1309),
#  ('associate', 1309),
#  ('meetings', 1308),
#  ('preparation', 1308),
#  ('events', 1307),
#  ('three', 1307),
#  ('duties', 1306),
#  ('february', 1306),
#  ('consulting', 1304),
#  ('mail', 1303),
#  ('basic', 1303),
#  ('action', 1301),
#  ('india', 1301),
#  ('digital', 1299),
#  ('economics', 1299),
#  ('food', 1299),
#  ('teams', 1298),
#  ('consultant', 1297),
#  ('teacher', 1297),
#  ('making', 1296),
#  ('manage', 1295),
#  ('growth', 1295),
#  ('members', 1294),
#  ('presentations', 1294),
#  ('appropriate', 1293),
#  ('completed', 1292),
#  ('resumes', 1292),
#  ('full', 1291),
#  ('internal', 1290),
#  ('java', 1289),
#  ('monthly', 1288),
#  ('coordinated', 1288),
#  ('master', 1288),
#  ('problem', 1287),
#  ('network', 1287),
#  ('burke', 1287),
#  ('managers', 1286),
#  ('line', 1286),
#  ('mississippi', 1286),
#  ('written', 1285),
#  ('number', 1285),
#  ('section', 1285),
#  ('user', 1285),
#  ('experiences', 1284),
#  ('operating', 1283),
#  ('certificate', 1282),
#  ('policy', 1282),
#  ('council', 1281),
#  ('chicago', 1279),
#  ('california', 1276),
#  ('children', 1276),
#  ('request', 1276),
#  ('contact', 1275),
#  ('month', 1275),
#  ('expertise', 1274),
#  ('maintenance', 1274),
#  ('area', 1273),
#  ('home', 1273),
#  ('case', 1272),
#  ('achievements', 1272),
#  ('courses', 1272),
#  ('dawson', 1272),
#  ('patients', 1272),
#  ('policies', 1271),
#  ('real', 1271),
#  ('model', 1271),
#  ('xxxx', 1270),
#  ('creative', 1269),
#  ('electrical', 1268),
#  ('division', 1268),
#  ('treatment', 1268),
#  ('chair', 1267),
#  ('world', 1267),
#  ('able', 1266),
#  ('internship', 1266),
#  ('website', 1266),
#  ('goals', 1265),
#  ('certified', 1265),
#  ('functional', 1264),
#  ('administrative', 1263),
#  ('local', 1263),
#  ('like', 1262),
#  ('accomplishments', 1262),
#  ('life', 1261),
#  ('awards', 1261),
#  ('creating', 1261),
#  ('dates', 1261),
#  ('club', 1261),
#  ('meet', 1260),
#  ('technologies', 1260),
#  ('supervised', 1259),
#  ('people', 1259),
#  ('problems', 1256),
#  ('different', 1255),
#  ('developer', 1255),
#  ('campus', 1255),
#  ('gallery', 1255),
#  ('global', 1254),
#  ('details', 1253),
#  ('tasks', 1252),
#  ('visual', 1252),
#  ('implant', 1252),
#  ('strategy', 1250),
#  ('multiple', 1249),
#  ('report', 1249),
#  ('power', 1249),
#  ('county', 1248),
#  ('resource', 1245),
#  ('template', 1244),
#  ('cell', 1244),
#  ('revenue', 1243),
#  ('html', 1243),
#  ('upon', 1243),
#  ('employer', 1243),
#  ('leader', 1241),
#  ('organizational', 1241),
#  ('contract', 1241),
#  ('companies', 1240),
#  ('analyzed', 1240),
#  ('commercial', 1240),
#  ('cash', 1239),
#  ('manufacturing', 1238),
#  ('techniques', 1238),
#  ('access', 1237),
#  ('proficient', 1237),
#  ('mobile', 1235),
#  ('government', 1235),
#  ('personnel', 1232),
#  ('record', 1232),
#  ('interests', 1232),
#  ('dayjob', 1232),
#  ('representative', 1232),
#  ('foundation', 1231),
#  ('pittsburgh', 1231),
#  ('standards', 1230),
#  ('required', 1230),
#  ('grant', 1227),
#  ('built', 1226),
#  ('scholarship', 1226),
#  ('handling', 1226),
#  ('recruitment', 1225),
#  ('spanish', 1225),
#  ('house', 1224),
#  ('status', 1224),
#  ('highly', 1223),
#  ('successfully', 1222),
#  ('experienced', 1222),
#  ('large', 1221),
#  ('assist', 1221),
#  ('interview', 1221),
#  ('entry', 1221),
#  ('involved', 1220),
#  ('stanford', 1220),
#  ('multi', 1220),
#  ('water', 1219),
#  ('designer', 1219),
#  ('relationship', 1218),
#  ('compliance', 1218),
#  ('format', 1218),
#  ('capital', 1218),
#  ('positions', 1218),
#  ('supervisor', 1217),
#  ('drive', 1216),
#  ('understanding', 1215),
#  ('records', 1215),
#  ('place', 1215),
#  ('following', 1215),
#  ('complex', 1214),
#  ('description', 1214),
#  ('extensive', 1213),
#  ('increased', 1213),
#  ('document', 1213),
#  ('banking', 1213),
#  ('press', 1212),
#  ('change', 1212),
#  ('firm', 1211),
#  ('powerpoint', 1211),
#  ('space', 1211),
#  ('read', 1210),
#  ('directed', 1210),
#  ('interest', 1210),
#  ('http', 1210),
#  ('processing', 1209),
#  ('long', 1209),
#  ('vice', 1208),
#  ('retail', 1208),
#  ('maintaining', 1207),
#  ('internet', 1207),
#  ('deans', 1207),
#  ('flight', 1207),
#  ('delivery', 1206),
#  ('illinois', 1206),
#  ('individual', 1206),
#  ('would', 1206),
#  ('relationships', 1205),
#  ('reference', 1204),
#  ('maintain', 1204),
#  ('post', 1204),
#  ('self', 1203),
#  ('server', 1203),
#  ('search', 1203),
#  ('simmons', 1203),
#  ('point', 1203),
#  ('united', 1202),
#  ('museum', 1202),
#  ('made', 1201),
#  ('weekly', 1201),
#  ('john', 1201),
#  ('certification', 1200),
#  ('solving', 1200),
#  ('unit', 1200),
#  ('canada', 1200),
#  ('decision', 1199),
#  ('please', 1199),
#  ('wrote', 1199),
#  ('expected', 1199),
#  ('implementing', 1199),
#  ('trained', 1198),
#  ('jacksonville', 1198),
#  ('profile', 1197),
#  ('opportunities', 1197),
#  ('documents', 1197),
#  ('head', 1197),
#  ('coordinator', 1197),
#  ('successful', 1197),
#  ('participated', 1197),
#  ('track', 1196),
#  ('seeking', 1196),
#  ('opportunity', 1196),
#  ('district', 1196),
#  ('travel', 1195),
#  ('oral', 1195),
#  ('direct', 1195),
#  ('patient', 1195),
#  ('coursework', 1195),
#  ('magazine', 1195),
#  ('several', 1194),
#  ('diploma', 1194),
#  ('analytical', 1193),
#  ('grade', 1193),
#  ('medicine', 1193),
#  ('healthcare', 1192),
#  ('schools', 1192),
#  ('integrated', 1192),
#  ('leading', 1191),
#  ('background', 1190),
#  ('evaluation', 1190),
#  ('road', 1190),
#  ('linux', 1189),
#  ('economic', 1188),
#  ('employers', 1187),
#  ('improve', 1187),
#  ('build', 1187),
#  ('practices', 1186),
#  ('chronological', 1186),
#  ('future', 1186),
#  ('statements', 1186),
#  ('improved', 1185),
#  ('gmail', 1185),
#  ('private', 1185),
#  ('established', 1185),
#  ('french', 1184),
#  ('increase', 1183),
#  ('levels', 1183),
#  ('documentation', 1183),
#  ('junior', 1183),
#  ('core', 1181),
#  ('south', 1181),
#  ('competition', 1181),
#  ('supervision', 1181),
#  ('publications', 1181),
#  ('functions', 1180),
#  ('cross', 1180),
#  ('regional', 1180),
#  ('impact', 1180),
#  ('academy', 1180),
#  ('security', 1179),
#  ('person', 1179),
#  ('potential', 1179),
#  ('obtain', 1179),
#  ('court', 1179),
#  ('store', 1179),
#  ('organizations', 1178),
#  ('across', 1178),
#  ('letters', 1177),
#  ('demonstrated', 1177),
#  ('undergraduate', 1177),
#  ('received', 1176),
#  ('months', 1176),
#  ('adobe', 1176),
#  ('small', 1175),
#  ('served', 1175),
#  ('schedule', 1175),
#  ('hours', 1175),
#  ('accountant', 1175),
#  ('oracle', 1174),
#  ('honor', 1174),
#  ('info', 1173),
#  ('prepare', 1173),
#  ('higher', 1173),
#  ('identify', 1173),
#  ('brand', 1173),
#  ('benefits', 1172),
#  ('carolina', 1172),
#  ('interpersonal', 1171),
#  ('questions', 1171),
#  ('oriented', 1171),
#  ('texas', 1171),
#  ('expert', 1170),
#  ('existing', 1169),
#  ('groups', 1169),
#  ('assessment', 1169),
#  ('industrial', 1169),
#  ('inventory', 1169),
#  ('minor', 1169),
#  ('migration', 1169),
#  ('tufts', 1169),
#  ('workshop', 1169),
#  ('detail', 1168),
#  ('effectively', 1168),
#  ('methods', 1168),
#  ('advertising', 1168),
#  ('thesis', 1168),
#  ('ensuring', 1167),
#  ('attended', 1167),
#  ('main', 1167),
#  ('taught', 1167),
#  ('many', 1166),
#  ('states', 1166),
#  ('helped', 1166),
#  ('principal', 1165),
#  ('associates', 1165),
#  ('london', 1165),
#  ('show', 1165),
#  ('seminar', 1165),
#  ('specialist', 1164),
#  ('code', 1164),
#  ('applied', 1164),
#  ('responsibility', 1163),
#  ('payroll', 1162),
#  ('researched', 1162),
#  ('models', 1162),
#  ('property', 1162),
#  ('artist', 1162),
#  ('complete', 1161),
#  ('cases', 1161),
#  ('outstanding', 1161),
#  ('material', 1160),
#  ('boston', 1160),
#  ('nursing', 1160),
#  ('flow', 1160),
#  ('corporation', 1159),
#  ('looking', 1159),
#  ('improvement', 1159),
#  ('chemical', 1159),
#  ('satisfaction', 1158),
#  ('contracts', 1158),
#  ('handled', 1158),
#  ('graduation', 1158),
#  ('chapter', 1158),
#  ('planned', 1158),
#  ('chinese', 1158),
#  ('indiana', 1157),
#  ('collaborated', 1156),
#  ('overall', 1156),
#  ('physical', 1156),
#  ('week', 1156),
#  ('implement', 1155),
#  ('location', 1155),
#  ('book', 1155),
#  ('therapy', 1155),
#  ('identified', 1154),
#  ('costs', 1154),
#  ('architecture', 1154),
#  ('enterprise', 1153),
#  ('achieved', 1153),
#  ('culture', 1153),
#  ('resulting', 1153),
#  ('look', 1153),
#  ('carnegie', 1153),
#  ('awarded', 1152),
#  ('integration', 1152),
#  ('since', 1152),
#  ('fashion', 1152),
#  ('teachers', 1152),
#  ('preparing', 1152),
#  ('fluent', 1152),
#  ('laboratory', 1151),
#  ('value', 1150),
#  ('advisory', 1150),
#  ('west', 1150),
#  ('central', 1150),
#  ('standard', 1150),
#  ('music', 1150),
#  ('want', 1150),
#  ('works', 1150),
#  ('type', 1149),
#  ('china', 1149),
#  ('advisor', 1149),
#  ('estate', 1149),
#  ('important', 1148),
#  ('evaluated', 1148),
#  ('force', 1148),
#  ('graphic', 1148),
#  ('reviewed', 1148),
#  ('sure', 1148),
#  ('white', 1148),
#  ('verbs', 1148),
#  ('portfolio', 1148),
#  ('departments', 1147),
#  ('monitoring', 1145),
#  ('vitae', 1145),
#  ('modeling', 1145),
#  ('reading', 1145),
#  ('setting', 1144),
#  ('plant', 1144),
#  ('concepts', 1144),
#  ('restorative', 1144),
#  ('perform', 1143),
#  ('environmental', 1143),
#  ('call', 1143),
#  ('throughout', 1143),
#  ('ideas', 1143),
#  ('great', 1143),
#  ('examples', 1143),
#  ('applying', 1142),
#  ('mellon', 1142),
#  ('homoeopathic', 1142),
#  ('statement', 1141),
#  ('promoted', 1141),
#  ('federal', 1141),
#  ('variety', 1141),
#  ('energy', 1140),
#  ('five', 1140),
#  ('transactions', 1140),
#  ('objectives', 1140),
#  ('open', 1139),
#  ('write', 1139),
#  ('ensured', 1139),
#  ('counseling', 1139),
#  ('alumni', 1139),
#  ('monash', 1139),
#  ('sciences', 1139),
#  ('possible', 1138),
#  ('external', 1138),
#  ('guide', 1138),
#  ('exceptional', 1138),
#  ('women', 1138),
#  ('take', 1138),
#  ('infrastructure', 1137),
#  ('proven', 1137),
#  ('kovner', 1137),
#  ('studio', 1137),
#  ('currently', 1137),
#  ('brown', 1136),
#  ('progress', 1136),
#  ('four', 1136),
#  ('youth', 1136),
#  ('wide', 1135),
#  ('officer', 1135),
#  ('suite', 1135),
#  ('consumer', 1135),
#  ('america', 1135),
#  ('chemistry', 1135),
#  ('efficiency', 1135),
#  ('focus', 1134),
#  ('skilled', 1134),
#  ('elementary', 1134),
#  ('autocad', 1134),
#  ('homoeopathy', 1134),
#  ('chawla', 1134),
#  ('follow', 1133),
#  ('prior', 1133),
#  ('middle', 1133),
#  ('designing', 1133),
#  ('credit', 1133),
#  ('orders', 1133),
#  ('trends', 1132),
#  ('park', 1132),
#  ('range', 1132),
#  ('facilitated', 1132),
#  ('aspects', 1132),
#  ('family', 1132),
#  ('regarding', 1131),
#  ('held', 1131),
#  ('focused', 1131),
#  ('users', 1131),
#  ('highlights', 1131),
#  ('dean', 1131),
#  ('electronic', 1130),
#  ('event', 1130),
#  ('distribution', 1130),
#  ('photoshop', 1130),
#  ('custom', 1130),
#  ('changes', 1129),
#  ('structure', 1129),
#  ('active', 1129),
#  ('francisco', 1129),
#  ('east', 1129),
#  ('artwork', 1129),
#  ('exhibition', 1129),
#  ('without', 1128),
#  ('final', 1128),
#  ('success', 1128),
#  ('scheduling', 1128),
#  ('hands', 1128),
#  ('markets', 1128),
#  ('angeles', 1128),
#  ('recent', 1128),
#  ('baltimore', 1128),
#  ('base', 1127),
#  ('initiatives', 1127),
#  ('critical', 1127),
#  ('instructor', 1127),
#  ('careers', 1127),
#  ('investment', 1127),
#  ('utilizing', 1127),
#  ('editor', 1127),
#  ('must', 1127),
#  ('qualification', 1126),
#  ('jobs', 1126),
#  ('term', 1126),
#  ('classroom', 1126),
#  ('unix', 1126),
#  ('delivered', 1125),
#  ('limited', 1125),
#  ('second', 1125),
#  ('avenue', 1125),
#  ('effects', 1125),
#  ('excellence', 1124),
#  ('positive', 1124),
#  ('keep', 1124),
#  ('awareness', 1124),
#  ('secondary', 1124),
#  ('telephone', 1124),
#  ('task', 1124),
#  ('pediatric', 1124),
#  ('principles', 1124),
#  ('motivated', 1123),
#  ('times', 1123),
#  ('compensation', 1122),
#  ('abilities', 1122),
#  ('tracking', 1122),
#  ('feedback', 1122),
#  ('delhi', 1122),
#  ('javascript', 1122),
#  ('professionals', 1122),
#  ('skill', 1121),
#  ('basis', 1121),
#  ('oversaw', 1121),
#  ('achievement', 1121),
#  ('selection', 1121),
#  ('assigned', 1121),
#  ('gained', 1121),
#  ('minnesota', 1121),
#  ('dynamic', 1120),
#  ('innovative', 1120),
#  ('need', 1120),
#  ('australia', 1120),
#  ('start', 1120),
#  ('pressure', 1120),
#  ('virginia', 1120),
#  ('produced', 1119),
#  ('diverse', 1119),
#  ('copy', 1119),
#  ('minneapolis', 1119),
#  ('style', 1119),
#  ('jackson', 1119),
#  ('significant', 1118),
#  ('others', 1118),
#  ('salary', 1118),
#  ('assisting', 1118),
#  ('nebraska', 1118),
#  ('matlab', 1118),
#  ('websites', 1117),
#  ('check', 1117),
#  ('hardware', 1117),
#  ('calls', 1116),
#  ('video', 1116),
#  ('source', 1116),
#  ('update', 1116),
#  ('hiring', 1115),
#  ('installation', 1115),
#  ('biomedical', 1115),
#  ('agency', 1115),
#  ('communicate', 1114),
#  ('conduct', 1114),
#  ('candidates', 1114),
#  ('assistance', 1114),
#  ('branch', 1114),
#  ('includes', 1114),
#  ('last', 1114),
#  ('occupational', 1114),
#  ('edition', 1114),
#  ('independent', 1114),
#  ('fixed', 1114),
#  ('approach', 1113),
#  ('efforts', 1113),
#  ('mysql', 1113),
#  ('green', 1113),
#  ('execution', 1112),
#  ('supply', 1112),
#  ('introduction', 1112),
#  ('sport', 1112),
#  ('classes', 1112),
#  ('size', 1112),
#  ('candidate', 1112),
#  ('lines', 1112),
#  ('analyze', 1111),
#  ('child', 1111),
#  ('negotiated', 1111),
#  ('contributed', 1111),
#  ('supported', 1111),
#  ('past', 1111),
#  ('emergency', 1111),
#  ('restaurant', 1111),
#  ('copyright', 1110),
#  ('sessions', 1110),
#  ('recommendations', 1110),
#  ('sept', 1110),
#  ('interface', 1110),
#  ('font', 1110),
#  ('profit', 1110),
#  ('firms', 1110),
#  ('generation', 1109),
#  ('short', 1109),
#  ('operational', 1109),
#  ('tool', 1109),
#  ('necessary', 1109),
#  ('birth', 1109),
#  ('performing', 1109),
#  ('proficiency', 1109),
#  ('residential', 1109),
#  ('graphics', 1109),
#  ('google', 1109),
#  ('photography', 1109),
#  ('published', 1109),
#  ('achieve', 1108),
#  ('creation', 1108),
#  ('interviews', 1108),
#  ('embedded', 1108),
#  ('reviews', 1108),
#  ('know', 1108),
#  ('body', 1108),
#  ('sponsor', 1108),
#  ('companys', 1107),
#  ('collection', 1107),
#  ('seminars', 1107),
#  ('platform', 1107),
#  ('needed', 1107),
#  ('disabilities', 1107),
#  ('analyzing', 1106),
#  ('conducting', 1106),
#  ('regular', 1106),
#  ('free', 1106),
#  ('centre', 1106),
#  ('budgets', 1106),
#  ('technician', 1106),
#  ('schedules', 1106),
#  ('completion', 1106),
#  ('apply', 1105),
#  ('single', 1105),
#  ('coordinating', 1105),
#  ('monitor', 1105),
#  ('attendance', 1105),
#  ('articles', 1105),
#  ('assembly', 1105),
#  ('properties', 1105),
#  ('maryland', 1105),
#  ('david', 1105),
#  ('guidelines', 1105),
#  ('learn', 1105),
#  ('coordinate', 1104),
#  ('every', 1104),
#  ('utilized', 1104),
#  ('certifications', 1104),
#  ('conferences', 1104),
#  ('pages', 1104),
#  ('news', 1104),
#  ('juried', 1104),
#  ('denver', 1104),
#  ('houston', 1104),
#  ('files', 1103),
#  ('competitive', 1103),
#  ('player', 1103),
#  ('sites', 1103),
#  ('specifications', 1103),
#  ('mass', 1103),
#  ('known', 1103),
#  ('solution', 1103),
#  ('describe', 1103),
#  ('library', 1103),
#  ('fund', 1103),
#  ('scholar', 1103),
#  ('mathematics', 1103),
#  ('workers', 1103),
#  ('deadlines', 1102),
#  ('front', 1102),
#  ('organizing', 1102),
#  ('affairs', 1102),
#  ('print', 1102),
#  ('facility', 1102),
#  ('session', 1102),
#  ('campaigns', 1102),
#  ('claims', 1101),
#  ('early', 1101),
#  ('controls', 1101),
#  ('resolution', 1101),
#  ('placement', 1101),
#  ('campaign', 1101),
#  ...]

# %%
pd.DataFrame(frequency_list).to_excel("C:\\Users\\Administrator\\Desktop\\data\\words.xls", encoding="utf-8")

# %%
for i in range(len(frequency_list)):
    if frequency_list[i][1]<1000:
        print(i)
        break
# Out:
# 6091

# %%
thousands=frequency_list[:6094]
new_dict={}
for tok in thousands:
    new_dict[tok[0]]=len(new_dict.keys())

# %%
#tokenizer.word_index=new_dictionary
tokenizer.word_index=new_dict

# %%
len(tokenizer.word_index)
# Out:
# 6094

# %%
resumes=tokenizer.texts_to_sequences(x_handled)

# %%
p_resume=pad_sequences(resumes, maxlen=max([len(resume) for resume in resumes]), padding='post')

# %%
max([len(resume)for resume in resumes])
# Out:
# 5057

# %% [markdown]
# 모델 생성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
x=p_resume
y=int_label

# %%
model=Sequential()
model.add(Embedding(6100,100))
model.add(LSTM(100))
model.add(Dense(25, activation='softmax'))

# %%
es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc=ModelCheckpoint('best_model.h5', monitor='val_acc',mode='max',verbose=1, save_best_only=True)

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['acc'])

# %%
x_arr=np.array(x)
y_arr=np.array(y)
x_train=x_arr[100:]
y_train=y_arr[100:]
x_test=x_arr[:100]
y_test=y_arr[:100]
history=model.fit(x_train,y_train,batch_size=128, epochs=3,
                  callbacks=[es,mc], validation_data=(x_train[:100],y_train[:100]))
# Out:
# Train on 889 samples, validate on 100 samples
# Epoch 1/3
# 768/889 [========================>.....] - ETA: 5s - loss: 3.0341 - acc: 0.1133
# Epoch 00001: val_acc did not improve from 0.00000
# 889/889 [==============================] - 41s 46ms/sample - loss: 3.0324 - acc: 0.1102 - val_loss: 2.6129 - val_acc: 0.0000e+00
# Epoch 2/3
# 768/889 [========================>.....] - ETA: 5s - loss: 2.9949 - acc: 0.0911
# Epoch 00002: val_acc did not improve from 0.00000
# 889/889 [==============================] - 41s 46ms/sample - loss: 2.9793 - acc: 0.0979 - val_loss: 2.7043 - val_acc: 0.0000e+00
# Epoch 3/3
# 768/889 [========================>.....] - ETA: 5s - loss: 2.9616 - acc: 0.1029
# Epoch 00003: val_acc did not improve from 0.00000
# 889/889 [==============================] - 41s 46ms/sample - loss: 2.9625 - acc: 0.1057 - val_loss: 2.6853 - val_acc: 0.0000e+00

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.feature_extraction.text import TfidfTransformer

# %%
df_new=pd.DataFrame()
x_list=[]
for i in range(len(x_handled)):
    resum=[]
    words=text_to_word_sequence(x_handled[i])
    for word in words:
        if word in new_dict.keys():
            resum.append(word)
    
    x_list.append(' '.join(resum))

print(len(x))
print(len(y))
df_new['resume']=x_list
df_new['category_vec']=y
# Out:
# 989
# 989

# %%
num_label=[]
for i in range(len(int_label)):
    num_label.append(int_label[i].index(1))

# %%
df_new['category_id']=num_label

# %%
word_label=[]
inv_dic = {v: k for k, v in dic.items()}
for i in range(len(num_label)):
    word_label.append(inv_dic[num_label[i]])

# %%
df_new['category_word']=word_label

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(8,6))
colors=['grey','grey','grey','grey','grey','grey','grey','grey','grey',
    'grey','grey','grey','grey','grey','grey','grey','grey','grey','grey','grey','orange','orange','orange','orange','orange']
df_new.groupby('category_word').resume.count().sort_values().plot.barh(ylim=0,color=colors,title='Distribution')
plt.xlabel('Number of occurrences', fontsize=10)
# Out:
# Text(0.5, 0, 'Number of occurrences')

# %%
tfidf=TfidfVectorizer(sublinear_tf=True,min_df=5,ngram_range=(1,2),stop_words='english')

features=tfidf.fit_transform(df_new.resume).toarray()

labels=df_new.category_id

# %%
print("Each of the %d complaints is represented by %d features (TF-IDF score of unigrams and bigrams)" %(features.shape))
# Out:
# Each of the 989 complaints is represented by 13749 features (TF-IDF score of unigrams and bigrams)

# %%
N = 5
for category_word, category_id in sorted(dic.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("\n==> %s:" %(category_word))
    print("  * Most Correlated Unigrams: %s" %(', '.join(unigrams[-N:])))
    print("  * Most Correlated Bigrams: %s" %(', '.join(bigrams[-N:])))

features_chi2=chi2(features, labels == 0)
indices=np.argsort(features_chi2[0])
feature_names=np.array(tfidf.get_feature_names())[indices]
# Out:
# ==> Accountant:
#   * Most Correlated Unigrams: reconciliations, accountants, chartered, accounting, accountant
#   * Most Correlated Bigrams: accounts payable, assistant accountant, account manager, chartered accountant, accountant resume
#
# ==> Advocate:
#   * Most Correlated Unigrams: arbitration, court, litigation, attorney, legal
#   * Most Correlated Bigrams: legal advice, juris doctor, personal injury, legal education, legal research
#
# ==> Agricultural:
#   * Most Correlated Unigrams: mower, agriculture, pest, plants, horticulture
#   * Most Correlated Bigrams: responsibilities responsible, florida languages, green house, pest control, achievement american
#
# ==> Apparel:
#   * Most Correlated Unigrams: interior, mica, textiles, showroom, fashion
#   * Most Correlated Bigrams: interior designer, color theory, fashion designer, interior design, space planning
#
# ==> Architects:
#   * Most Correlated Unigrams: dhabi, revit, highways, tower, drawings
#   * Most Correlated Bigrams: presently working, project documentation, customers regarding, indian english, preparation project
#
# ==> Arts:
#   * Most Correlated Unigrams: film, actor, hair, theatre, artist
#   * Most Correlated Bigrams: group exhibitions, texas austin, fine arts, special effects, height weight
#
# ==> Automobile:
#   * Most Correlated Unigrams: motors, vehicles, mechanic, automobile, automotive
#   * Most Correlated Bigrams: summary qualification, michigan phone, present house, automotive engineering, experience automotive
#
# ==> Aviation:
#   * Most Correlated Unigrams: aviation, cabin, passengers, attendant, flight
#   * Most Correlated Bigrams: safety procedures, present performed, university connecticut, attendant resume, flight attendant
#
# ==> BPO:
#   * Most Correlated Unigrams: simon, agent, calls, complaints, outbound
#   * Most Correlated Bigrams: term career, build career, management working, service level, experience center
#
# ==> Banking:
#   * Most Correlated Unigrams: teller, loan, tellers, bank, banking
#   * Most Correlated Bigrams: professional references, corporate banking, experiences bank, position bank, career experiences
#
# ==> Building & Construction:
#   * Most Correlated Unigrams: subcontractors, estimating, superintendent, subcontractor, construction
#   * Most Correlated Bigrams: planning cost, experience construction, site safety, construction projects, construction supervisor
#
# ==> Business Development:
#   * Most Correlated Unigrams: documenting, business, traceability, sdlc, analyst
#   * Most Correlated Bigrams: business requirements, experience business, user acceptance, acceptance testing, business analyst
#
# ==> Consultant:
#   * Most Correlated Unigrams: facilitation, warehousing, seoul, walter, consultant
#   * Most Correlated Bigrams: seoul korea, operations successfully, management coordination, management consulting, management consultant
#
# ==> Designing:
#   * Most Correlated Unigrams: illustrator, photography, photographer, graphic, designer
#   * Most Correlated Bigrams: print design, user experience, information architecture, graphic design, graphic designer
#
# ==> Digital Media:
#   * Most Correlated Unigrams: social, facebook, twitter, circulation, media
#   * Most Correlated Bigrams: online marketing, digital marketing, media manager, mass communication, social media
#
# ==> Education:
#   * Most Correlated Unigrams: students, teachers, elementary, classroom, teacher
#   * Most Correlated Bigrams: middle school, education teacher, physical education, elementary school, special education
#
# ==> Engineering:
#   * Most Correlated Unigrams: engineer, matlab, engineers, fresher, engineering
#   * Most Correlated Bigrams: engineering resume, chemical engineering, electrical engineering, civil engineering, mechanical engineering
#
# ==> Finance:
#   * Most Correlated Unigrams: forecasts, financials, accounting, financial, finance
#   * Most Correlated Bigrams: senior finance, financial analyst, financial operations, finance manager, financial data
#
# ==> Food & Beverages:
#   * Most Correlated Unigrams: food, culinary, restaurant, waitress, chef
#   * Most Correlated Bigrams: serving meals, serving food, knowledge food, culinary arts, food service
#
# ==> HR:
#   * Most Correlated Unigrams: satheesh, generalist, recruitment, downloadmela, compensation
#   * Most Correlated Bigrams: benefits compensation, exit interviews, human resource, employee relations, human resources
#
# ==> Health & Fitness:
#   * Most Correlated Unigrams: medicine, patient, hospital, dental, patients
#   * Most Correlated Bigrams: medical center, internal medicine, medical college, health care, patient care
#
# ==> Information Technology:
#   * Most Correlated Unigrams: mysql, linux, android, java, developer
#   * Most Correlated Bigrams: information technology, open source, java developer, software engineer, computer science
#
# ==> Managment:
#   * Most Correlated Unigrams: million, retailer, brooklyn, substation, manager
#   * Most Correlated Bigrams: restaurant manager, marketing manager, senior marketing, quarterly sales, manager resume
#
# ==> Public Relations:
#   * Most Correlated Unigrams: tokyo, credits, marina, commended, sydney
#   * Most Correlated Bigrams: good experience, present customer, sales supervisor, tokyo japan, cash handling
#
# ==> Sales:
#   * Most Correlated Unigrams: representative, representatives, latin, price, sales
#   * Most Correlated Bigrams: negotiations clients, queries responsible, generating analyzing, analyzing monthly, sales representative

# %%
X=df_new['resume']
y_list=[]

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.1, random_state=0)

# %%
models=[ RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

# 5 Cross-validation
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
    
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %%
mean_accuracy = cv_df.groupby('model_name').accuracy.mean()
std_accuracy = cv_df.groupby('model_name').accuracy.std()

acc = pd.concat([mean_accuracy, std_accuracy], axis= 1, 
          ignore_index=True)
acc.columns = ['Mean Accuracy', 'Standard deviation']
acc
# Out:
#                         Mean Accuracy  Standard deviation
# model_name
# LinearSVC                    0.704779            0.051030
# LogisticRegression           0.594550            0.025401
# MultinomialNB                0.421668            0.018629
# RandomForestClassifier       0.513659            0.016537

# %%
X_train, X_test, y_train, y_test,indices_train,indices_test = train_test_split(features, 
                                                               labels, 
                                                               df_new.index, test_size=0.3, 
                                                               random_state=1)

model = LinearSVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("LinearSVC Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# LinearSVC Accuracy: 69.36%

# %%
from sklearn import metrics


print('\t\t   CLASSIFICATION METRICS FOR SVM\n')
print(metrics.classification_report(y_test, y_pred, 
                                    target_names= df_new['category_word'].unique()))
print("LinearSVC Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# 		   CLASSIFICATION METRICS FOR SVM
#
#                          precision    recall  f1-score   support
#
#                      HR       0.71      1.00      0.83        10
#               Designing       0.50      0.71      0.59        14
#               Managment       0.38      0.25      0.30        20
#  Information Technology       0.49      0.72      0.58        25
#               Education       0.62      0.75      0.68        20
#                Advocate       0.92      0.75      0.83        16
#    Business Development       0.21      0.30      0.25        10
#        Health & Fitness       0.62      0.87      0.72        15
#            Agricultural       1.00      0.57      0.73         7
#                     BPO       0.80      0.57      0.67         7
#                   Sales       0.53      0.73      0.62        11
#              Consultant       0.33      0.12      0.18         8
#           Digital Media       0.50      0.54      0.52        13
#              Automobile       1.00      0.40      0.57         5
#        Food & Beverages       0.71      0.56      0.63         9
#                 Finance       0.69      0.47      0.56        19
#                 Apparel       0.00      0.00      0.00         5
#             Engineering       0.55      0.75      0.63        24
#              Accountant       0.76      0.62      0.68        21
# Building & Construction       0.83      0.56      0.67         9
#              Architects       0.00      0.00      0.00         3
#        Public Relations       0.50      0.20      0.29         5
#                 Banking       0.75      0.50      0.60         6
#                    Arts       0.75      0.75      0.75        12
#                Aviation       1.00      1.00      1.00         3
#
#                accuracy                           0.60       297
#               macro avg       0.61      0.55      0.55       297
#            weighted avg       0.61      0.60      0.59       297
#
# LinearSVC Accuracy: 69.36%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt='d',
            xticklabels=dic.keys(), 
            yticklabels=dic.keys())
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX - LinearSVC\n", size=16);

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

# %%
model1=XGBClassifier()
model1.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred=model1.predict(X_test)

# %%
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)

print('\t\t   CLASSIFICATION METRICS FOR XGB\n')
print(metrics.classification_report(y_test, y_pred, 
                                    target_names= df_new['category_word'].unique()))
print("XGBoost Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# 		   CLASSIFICATION METRICS FOR XGB
#
#                          precision    recall  f1-score   support
#
#                      HR       0.71      1.00      0.83        10
#               Designing       0.50      0.71      0.59        14
#               Managment       0.38      0.25      0.30        20
#  Information Technology       0.49      0.72      0.58        25
#               Education       0.62      0.75      0.68        20
#                Advocate       0.92      0.75      0.83        16
#    Business Development       0.21      0.30      0.25        10
#        Health & Fitness       0.62      0.87      0.72        15
#            Agricultural       1.00      0.57      0.73         7
#                     BPO       0.80      0.57      0.67         7
#                   Sales       0.53      0.73      0.62        11
#              Consultant       0.33      0.12      0.18         8
#           Digital Media       0.50      0.54      0.52        13
#              Automobile       1.00      0.40      0.57         5
#        Food & Beverages       0.71      0.56      0.63         9
#                 Finance       0.69      0.47      0.56        19
#                 Apparel       0.00      0.00      0.00         5
#             Engineering       0.55      0.75      0.63        24
#              Accountant       0.76      0.62      0.68        21
# Building & Construction       0.83      0.56      0.67         9
#              Architects       0.00      0.00      0.00         3
#        Public Relations       0.50      0.20      0.29         5
#                 Banking       0.75      0.50      0.60         6
#                    Arts       0.75      0.75      0.75        12
#                Aviation       1.00      1.00      1.00         3
#
#                accuracy                           0.60       297
#               macro avg       0.61      0.55      0.55       297
#            weighted avg       0.61      0.60      0.59       297
#
# XGBoost Accuracy: 59.93%

# %%
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt='d',
            xticklabels=dic.keys(), 
            yticklabels=dic.keys())
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX - XGBoost\n", size=16);

# %%
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("XGBoost Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# XGBoost Accuracy: 59.93%

# %% [markdown]
# linearSVC가 낫구나....

# %%
import pickle

filename='finalModel.sav'
pickle.dump(model, open(filename,'wb'))
